# %%
import style2
# Out:
# 2022-05-31 15:43:19.630250: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-31 15:43:19.630287: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
path_content = 'img/c40-recharge-scattered-gallery-1-4x3.jpg'
path_style = 'img/style_line_waves.jpeg'

# %%
style = style2.StyleTransfer(path_content, path_style)
# Out:
# 2022-05-31 15:43:23.768187: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-31 15:43:23.768223: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-31 15:43:23.768247: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (snp-0): /proc/driver/nvidia/version does not exist
# 2022-05-31 15:43:23.768480: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
style.show_inputs()

# %%
style.optimize(2000)
# Out:
# Iteration: 1999
# Total loss: 7.36e+05, style loss: 2.77e+05, content loss: 4.59e+05, time: 0.0840s

# %%
style.show_results()

# %%
style.show_inputs()

# %%
style.optimize(2000)
# Out:
# Iteration: 486
# Total loss: 5.54e+05, style loss: 1.75e+05, content loss: 3.80e+05, time: 0.1022s

# %%
style.show_results()

# %%
style.show_inputs()
