# %%
import pandas as pd

wd = '/Users/ewenwang/Documents/practice_data/'
file = 'regulation.csv'

data = pd.read_csv(wd+file)
data.head()
# Out:
#    序号            企业名称     组织机构代码               注册地址              生产地址  \
# 0   1  上海巴士五汽公共交通有限公司  607392127       上海市共和新路３０３４号            南陈路98号
# 1   2    上海康志物业管理有限公司   86158393    上海市宝山区锦秋路４８号Ｇ１５   上海市宝山区锦秋路４８号Ｇ１５
# 2   3    上海地矿物业管理有限公司  630350240     上海市沪太路１０６３弄５号甲           灵石路930号
# 3   4         上海立新五金厂  132808298  上海市静安区南京西路１９５５弄９号            南陈路24号
# 4   5      上海同祁置业有限公司  586791275   上海市宝山区锦秋路４８号Ｆ１３８  上海市宝山区锦秋路４８号Ｆ１３８
#
#           检查日期    处理措施
# 0  1/8/10 1:01  未发现问题。
# 1  1/8/10 8:01  未发现问题。
# 2  1/8/10 9:01  未发现问题。
# 3  1/8/10 9:01  未发现问题。
# 4  1/8/10 9:01  未发现问题。

# %%
data.shape
# Out:
# (36672, 7)

# %%
import Linkage

# %%
Linkage.Linkage(data, None, name='企业名称', n_sample=1000, bin_size=500, method='jarowinkler', threshold=0.93).multiProcess('record_0629.log', 'results.csv')
# Out:
# n_sample: 1000	bin_size: 500	method: jarowinkler	threshold: 0.93
# (18905, 30656)  上海市浦东新区金童幼儿园    上海市浦东新区华林幼儿园
# (34804, 23487)  上海新怡物业管理有限公司    上海怡朋物业管理有限公司
# (34804, 16638)  上海新怡物业管理有限公司    上海新果物业管理有限公司
#  (6771, 12354)  上海复瑞物业管理有限公司  上海复欣物业管理发展有限公司
#   (6771, 8339)  上海复瑞物业管理有限公司    上海瑞强物业管理有限公司
#
# time spend: 0.0 hours
#              pairs            company_1            company_2
# 0   (18905, 30656)         上海市浦东新区金童幼儿园         上海市浦东新区华林幼儿园
# 1   (34804, 23487)         上海新怡物业管理有限公司         上海怡朋物业管理有限公司
# 2   (34804, 16638)         上海新怡物业管理有限公司         上海新果物业管理有限公司
# 3    (6771, 12354)         上海复瑞物业管理有限公司       上海复欣物业管理发展有限公司
# 4     (6771, 8339)         上海复瑞物业管理有限公司         上海瑞强物业管理有限公司
# 5   (20692, 30656)         上海市浦东新区西门幼儿园         上海市浦东新区华林幼儿园
# 8   (12900, 36230)        上海农工商崮山超市有限公司        上海农工商宝山超市有限公司
# 9   (12900, 34616)        上海农工商崮山超市有限公司        上海农工商青浦超市有限公司
# 10  (28899, 28848)    上海市浦东新区孙桥社区卫生服务中心    上海市浦东新区张江社区卫生服务中心
# ...
