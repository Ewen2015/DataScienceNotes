# %%
import GridSearch

# %%
gs = GridSearch.Results(log_path='/Users/ewenwang/Box Sync/project_bocomm_2019/report/data/DLV_gridsearch.csv')

# %%
# %matplotlib notebook
gs.getVisual(4)
# Out:
# <img src="data:image/png;base64,..." width="640">
#      max_depth  subsample  colsample_bytree  best_rounds  train_aucpr_mean  \
# 925        4.0       0.85              0.45         4524          0.817935
#
#      train_aucpr_std  test_aucpr_mean  test_aucpr_std
# 925         0.003454         0.380165        0.010292

# %%
gs.getVisual(5)
# Out:
# <img src="data:image/png;base64,..." width="640">
#       max_depth  subsample  colsample_bytree  best_rounds  train_aucpr_mean  \
# 1249        5.0       0.85              0.45         2900          0.852381
#
#       train_aucpr_std  test_aucpr_mean  test_aucpr_std
# 1249         0.002917         0.381533        0.011347

# %%
gs.getVisual(6)
# Out:
# <img src="data:image/png;base64,..." width="640">
#       max_depth  subsample  colsample_bytree  best_rounds  train_aucpr_mean  \
# 1536        6.0       0.75               0.4         2005          0.864236
#
#       train_aucpr_std  test_aucpr_mean  test_aucpr_std
# 1536         0.002023         0.381032        0.010337
